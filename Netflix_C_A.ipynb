# %% [markdown]
# <a href="https://colab.research.google.com/github/aryangaikwad-12max/Netflix_Content_Analysis-NCA/blob/main/Netflix_C_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================================
# 1️⃣  SETUP
# ==========================================================
# !pip install nltk scikit-learn wordcloud seaborn matplotlib --quiet

import pandas as pd, numpy as np, re
import matplotlib.pyplot as plt, seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
import nltk
from wordcloud import WordCloud
from collections import Counter

nltk.download('stopwords', quiet=True)
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (9,5)

# ==========================================================
# 2️⃣  LOAD DATA
# ==========================================================
# Make sure the file name matches exactly your uploaded file
df = pd.read_csv('netflix_titles.csv')
print("Shape:", df.shape)
df.head()

# ==========================================================
# 3️⃣  CLEANING & FEATURE ENGINEERING
# ==========================================================
df.columns = df.columns.str.strip().str.lower()

# Handle missing values
df['type']        = df['type'].str.title().fillna('Unknown')
df['listed_in']   = df['listed_in'].fillna('')
df['country']     = df['country'].fillna('Unknown').apply(lambda x: x.split(',')[0].strip())
df['description'] = df['description'].fillna('')

# Convert date
if 'date_added' in df.columns:
    df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
    df['year_added'] = df['date_added'].dt.year

# Runtime extraction
def parse_runtime(x):
    if pd.isna(x): return np.nan
    m = re.search(r'(\d+)\s*min', str(x))
    if m: return int(m.group(1))
    s = re.search(r'(\d+)\s*Season', str(x))
    if s: return int(s.group(1))*30
    return np.nan

if 'duration' in df.columns:
    df['runtime_min'] = df['duration'].apply(parse_runtime)

# Genre list
df['genres'] = df['listed_in'].apply(lambda x: [g.strip() for g in str(x).split(',')])

# Combined text for NLP
df['text'] = (
    df['title'].fillna('') + '. ' +
    df['description'].fillna('') + '. ' +
    df['listed_in'].fillna('')
)

print("Columns now:", df.columns.tolist())
print("Missing values:\n", df.isna().sum().sort_values(ascending=False).head())

# ==========================================================
# 4️⃣  EXPLORATORY DATA ANALYSIS
# ==========================================================
# Type distribution
sns.countplot(x='type', data=df, order=df['type'].value_counts().index)
plt.title('Content Type Distribution')
plt.show()

# Top Genres
genre_count = Counter([g for sub in df['genres'] for g in sub if g])
top_genres = pd.DataFrame(genre_count.most_common(15), columns=['Genre','Count'])
sns.barplot(y='Genre', x='Count', data=top_genres)
plt.title('Top 15 Genres on Netflix')
plt.show()

# Titles Added per Year
if 'year_added' in df.columns:
    df['year_added'].dropna().astype(int).value_counts().sort_index().plot(marker='o')
    plt.title('Titles Added Per Year')
    plt.xlabel('Year Added'); plt.ylabel('Number of Titles')
    plt.show()

# Runtime distribution
if 'runtime_min' in df.columns and df['runtime_min'].notna().sum()>0:
    sns.histplot(df[df['type']=='Movie']['runtime_min'].dropna(), bins=30)
    plt.title('Runtime Distribution (Movies)')
    plt.xlabel('Minutes'); plt.show()

# Country distribution (top 10)
top_countries = df['country'].value_counts().head(10)
sns.barplot(x=top_countries.values, y=top_countries.index)
plt.title('Top 10 Countries Producing Netflix Content')
plt.xlabel('Number of Titles')
plt.show()

# ==========================================================
# 5️⃣  TEXT PREPROCESSING
# ==========================================================
def clean_text(t):
    t = t.lower()
    t = re.sub(r'http\S+', '', t)
    t = re.sub(r'[^a-z0-9\s]', ' ', t)
    toks = [w for w in t.split() if w not in stop_words and len(w)>2]
    return ' '.join(toks)

df['text_clean'] = df['text'].apply(clean_text)

# WordCloud for fun
wc = WordCloud(width=900, height=400, background_color='white').generate(" ".join(df['text_clean']))
plt.imshow(wc, interpolation='bilinear'); plt.axis('off'); plt.title('WordCloud of Descriptions'); plt.show()

# ==========================================================
# 6️⃣  TF-IDF + KMeans CLUSTERING
# ==========================================================
tfidf = TfidfVectorizer(max_df=0.7, min_df=5, max_features=5000)
X = tfidf.fit_transform(df['text_clean'])

k = 8
kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

terms = tfidf.get_feature_names_out()
order = kmeans.cluster_centers_.argsort()[:, ::-1]
for i in range(k):
    top = [terms[ind] for ind in order[i,:10]]
    print(f"Cluster {i} → {' , '.join(top)}")

sns.countplot(x='cluster', data=df)
plt.title('Titles per Cluster')
plt.show()

# ==========================================================
# 7️⃣  CONTENT-BASED RECOMMENDER
# ==========================================================
def recommend(title, top_n=10):
    if title not in df['title'].values:
        print("Title not found."); return pd.DataFrame()
    idx = df[df['title']==title].index[0]
    vec = X[idx]
    sims = cosine_similarity(vec, X).flatten()
    sim_idx = sims.argsort()[::-1][1:top_n+1]
    return df.iloc[sim_idx][['title','type','listed_in','description']]

# 🔍 Example
recos = recommend('House of Cards', top_n=5)
display(recos)

# ==========================================================
# 8️⃣  SAVE RESULTS
# ==========================================================
df.to_csv('netflix_with_clusters.csv', index=False)
print("✅ Saved: netflix_with_clusters.csv")

# ==========================================================
# 🔥  IMPROVED RECOMMENDER SYSTEM (TEXT + GENRE + CAST + COUNTRY)
# ==========================================================
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MultiLabelBinarizer, MinMaxScaler

# Step 1️⃣: Handle missing key fields
for col in ['cast', 'country', 'listed_in']:
    df[col] = df[col].fillna('')

# Step 2️⃣: Process lists for genres, cast, and country
df['genres'] = df['listed_in'].apply(lambda x: [i.strip() for i in str(x).split(',') if i.strip()])
df['cast_list'] = df['cast'].apply(lambda x: [i.strip() for i in str(x).split(',') if i.strip()])
df['country_list'] = df['country'].apply(lambda x: [i.strip() for i in str(x).split(',') if i.strip()])

# Step 3️⃣: Encode multi-label features
mlb_genre = MultiLabelBinarizer()
mlb_cast = MultiLabelBinarizer()
mlb_country = MultiLabelBinarizer()

genre_encoded = mlb_genre.fit_transform(df['genres'])
cast_encoded = mlb_cast.fit_transform(df['cast_list'])
country_encoded = mlb_country.fit_transform(df['country_list'])

# Step 4️⃣: Compute similarity matrices
tfidf = TfidfVectorizer(stop_words='english', max_features=7000)
text_features = tfidf.fit_transform(df['text_clean'])

text_sim = cosine_similarity(text_features)
genre_sim = cosine_similarity(genre_encoded)
cast_sim = cosine_similarity(cast_encoded)
country_sim = cosine_similarity(country_encoded)

# Step 5️⃣: Weighted hybrid similarity
# You can tune these weights (must sum up roughly to 1.0)
alpha_text, alpha_genre, alpha_cast, alpha_country = 0.6, 0.2, 0.15, 0.05

hybrid_sim = (
    alpha_text * text_sim +
    alpha_genre * genre_sim +
    alpha_cast * cast_sim +
    alpha_country * country_sim
)

# Step 6️⃣: Recommendation function
def recommend_hybrid(title, top_n=10):
    if title not in df['title'].values:
        print("❌ Title not found in dataset.")
        return pd.DataFrame()

    idx = df[df['title'] == title].index[0]
    sims = hybrid_sim[idx]
    indices = sims.argsort()[::-1][1:top_n+1]
    recs = df.iloc[indices][['title', 'type', 'listed_in', 'cast', 'country', 'description']].copy()
    recs['similarity_score'] = sims[indices]
    return recs

# Step 7️⃣: Try some examples
example_titles = ["Breaking Bad", "Stranger Things", "Money Heist", "House of Cards"]

for title in example_titles:
    if title in df['title'].values:
        print(f"\n🎬 Recommendations similar to: {title}\n")
        display(recommend_hybrid(title, top_n=5))
# Out:
# Shape: (8807, 12)
# Columns now: ['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added', 'release_year', 'rating', 'duration', 'listed_in', 'description', 'year_added', 'runtime_min', 'genres', 'text']
# Missing values:
#  director      2634
# cast           825
# date_added      98
# year_added      98
# rating           4
# dtype: int64
# Cluster 0 → children , family , movies , comedies , christmas , save , bheem , new , friends , little
# Cluster 1 → kids , docuseries , comedies , reality , series , shows , world , friends , science , nature
# Cluster 2 → shows , international , crime , romantic , dramas , series , spanish , language , british , love
# Cluster 3 → movies , dramas , international , comedies , independent , romantic , love , young , man , woman
# Cluster 4 → documentaries , documentary , movies , music , musicals , sports , international , life , world , film
# Cluster 5 → thrillers , horror , movies , international , dramas , independent , young , woman , home , mysterious
# Cluster 6 → stand , comedy , comedian , special , comic , talk , stage , show , live , takes
# Cluster 7 → action , adventure , movies , international , fantasy , sci , dramas , comedies , man , mission
#                          title     type  \
# 1201  Abla Fahita: Drama Queen  Tv Show
# 6272          Before the Flood    Movie
# 1701     American Horror Story  Tv Show
# 526    Orange Is the New Black  Tv Show
# 3904              The Ruthless    Movie
#
#                                               listed_in  \
# 1201  Crime TV Shows, International TV Shows, TV Com...
# 6272                                      Documentaries
# 1701              TV Horror, TV Mysteries, TV Thrillers
# 526                              TV Comedies, TV Dramas
# 3904                       Dramas, International Movies
#
#                                             description
# 1201  Falsely incriminated, Abla Fahita is separated...
# 6272  Leonardo DiCaprio crisscrosses the globe to in...
# 1701  This twisted Emmy-winning drama plays upon the...
# 526   A privileged New Yorker ends up in a women's p...
# 3904  A rebellious teen grows up to become one of Mi...
# ✅ Saved: netflix_with_clusters.csv
#
# 🎬 Recommendations similar to: Breaking Bad
#                     title     type                                listed_in  \
# 2931     Better Call Saul  Tv Show   Crime TV Shows, TV Comedies, TV Dramas
# 1477              Dare Me  Tv Show  Crime TV Shows, TV Dramas, TV Thrillers
# 2767                Ozark  Tv Show  Crime TV Shows, TV Dramas, TV Thrillers
# 3801            WHAT / IF  Tv Show                  TV Dramas, TV Thrillers
# 3762  Designated Survivor  Tv Show  Crime TV Shows, TV Dramas, TV Thrillers
#
#                                                    cast        country  \
# 2931  Bob Odenkirk, Jonathan Banks, Michael McKean, ...  United States
# 1477  Willa Fitzgerald, Herizen Guardiola, Marlo Kel...  United States
# 2767  Jason Bateman, Sofia Hublitz, Laura Linney, Sk...  United States
# 3801  Renée Zellweger, Jane Levy, Blake Jenner, Keit...  United States
# 3762  Kiefer Sutherland, Natascha McElhone, Maggie Q...  United States
#
#                                             description  similarity_score
# 2931  This Emmy-nominated prequel to "Breaking Bad" ...          0.334808
# 1477  Relationships topple and loyalties flip when a...          0.319680
# 2767  A financial adviser drags his family from Chic...          0.306028
# 3801  Desperate to secure funding for her med tech s...          0.288548
# 3762  America's fate rests in the hands of a low-lev...          0.287098
# 🎬 Recommendations similar to: Stranger Things
#                                title     type  \
# 5200          Beyond Stranger Things  Tv Show
# 3187                     Nightflyers  Tv Show
# 6953                           Helix  Tv Show
# 1473  Chilling Adventures of Sabrina  Tv Show
# 241                         Manifest  Tv Show
#
#                                               listed_in  \
# 5200  Stand-Up Comedy & Talk Shows, TV Mysteries, TV...
# 3187       TV Horror, TV Mysteries, TV Sci-Fi & Fantasy
# 6953       TV Horror, TV Mysteries, TV Sci-Fi & Fantasy
# 1473       TV Horror, TV Mysteries, TV Sci-Fi & Fantasy
# 241        TV Dramas, TV Mysteries, TV Sci-Fi & Fantasy
#
#                                                    cast        country  \
# 5200  Jim Rash, Matt Duffer, Ross Duffer, Shawn Levy...  United States
# 3187  Eoin Macken, David Ajala, Jodie Turner-Smith, ...  United States
# 6953  Billy Campbell, Hiroyuki Sanada, Kyra Zagorsky...  United States
# 1473  Kiernan Shipka, Ross Lynch, Miranda Otto, Lucy...  United States
# 241   Melissa Roxburgh, Josh Dallas, Athena Karkanis...  United States
#
#                                             description  similarity_score
# 5200  Secrets from the "Stranger Things 2" universe ...          0.444721
# 3187  With humankind's future at stake, a group of s...          0.329673
# 6953  While investigating a possible outbreak at an ...          0.323600
# 1473  Magic and mischief collide as half-human, half...          0.303849
# 241   When a plane mysteriously lands years after ta...          0.285978
# 🎬 Recommendations similar to: House of Cards
#                          title     type  \
# 3762       Designated Survivor  Tv Show
# 6146          American Odyssey  Tv Show
# 3065                   Messiah  Tv Show
# 5147  TURN: Washington's Spies  Tv Show
# 5744               Containment  Tv Show
#
#                                     listed_in  \
# 3762  Crime TV Shows, TV Dramas, TV Thrillers
# 6146                  TV Dramas, TV Thrillers
# 3065                  TV Dramas, TV Thrillers
# 5147                                TV Dramas
# 5744                  TV Dramas, TV Thrillers
#
#                                                    cast        country  \
# 3762  Kiefer Sutherland, Natascha McElhone, Maggie Q...  United States
# 6146  Anna Friel, Peter Facinelli, Jake Robinson, Ji...  United States
# 3065  Michelle Monaghan, Mehdi Dehbi, John Ortiz, To...  United States
# 5147  Jamie Bell, Seth Numrich, Daniel Henshall, Hea...  United States
# 5744  David Gyasi, Christina Marie Moses, Chris Wood...  United States
#
#                                             description  similarity_score
# 3762  America's fate rests in the hands of a low-lev...          0.316025
# 6146  An elite soldier, a corporate lawyer and a pol...          0.297752
# 3065  A wary CIA officer investigates a charismatic ...          0.296050
# 5147  Set in 1778, this period drama recounts the st...          0.284863
# 5744  When a ferocious contagion sweeps through Atla...          0.269646
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('title').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('listed_in').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('description').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['type'].value_counts()
#     for x_label, grp in _df_6.groupby('title')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('title')
# _ = plt.ylabel('type')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['listed_in'].value_counts()
#     for x_label, grp in _df_7.groupby('type')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('type')
# _ = plt.ylabel('listed_in')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['description'].value_counts()
#     for x_label, grp in _df_8.groupby('listed_in')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('listed_in')
# _ = plt.ylabel('description')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_9['title'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_9, x='index', y='title', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_10['type'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_10, x='index', y='type', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_11['listed_in'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_11, x='index', y='listed_in', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_12['description'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_12, x='index', y='description', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
